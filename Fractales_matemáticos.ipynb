# %%
# Paquetes !

import matplotlib.pyplot as plt
from PIL import Image
from ipywidgets import interact,interactive, widgets
from random import randint
import sympy as spp
import numpy as np
from sympy.parsing.sympy_parser import parse_expr
from IPython.display import display, Markdown
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.figure as fg
from matplotlib import cm 

x,y,z = spp.symbols('x y z')

# %%
def newton(Funcion) :
    try: 
        def newton3D(Tres_Dimensiones):
            fig = plt.figure(figsize = (14,7)) 
            ax = fig.add_subplot(111, projection='3d')
            ax.view_init(azim=-90,elev=50) 
            ax.dist = 4.5; M = 200 # pixels

            if Tres_Dimensiones == 'Gráfica 1':
                dx = 0.0 ; dy = 0.0; L = 1.0; ax.set_facecolor([.85,.85,.45])
                def f(Z): 
                    return np.e**(-np.abs(Z))
                x = np.linspace(-L+dx,L+dx,M); y = np.linspace(-L+dy,L+dy,M)
                X,Y = np.meshgrid(x,y); Z = X + 1j*Y 
                for k in range(9): 
                    ZZ = Z - (Z**4+1)/(4*Z**3)
                    Z = ZZ
                    W = f(Z) 
                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-2.5*L,2*L)
                ax.plot_surface(X, Y, -W, rstride=1, cstride=1, cmap="terrain")
                plt.show()

            if Tres_Dimensiones == 'Gráfica 2':
                dx = 0.0 ; dy = 0.0; L = 1.3; ax.set_facecolor([1.,.6,.15])
                def f(Z): # def scale damping of the depth function
                    return np.e**(-np.abs(Z))
                x = np.linspace(-L+dx,L+dx,M); y = np.linspace(-L+dy,L+dy,M)
                X,Y = np.meshgrid(x,y); Z = X + 1j*Y 
                for k in range(10): 
                    ZZ = Z - (Z**4 + 1)/(4*Z**3)
                    Z = ZZ
                    W = f(Z)
                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-3.5*L,4*L)
                surf = ax.plot_surface(X, Y, -W, rstride=1, cstride=1, cmap="inferno")
                plt.show()

            if Tres_Dimensiones == 'Gráfica 3':
                dx = 0.0 ; dy = 0.0; L = 1.3; ax.set_facecolor([1.,.6,.15])
                def f(Z): # def scale damping of the depth function
                    return np.e**(-np.abs(Z))
                x = np.linspace(-L+dx,L+dx,M); y = np.linspace(-L+dy,L+dy,M)
                X,Y = np.meshgrid(x,y); Z = X + 1j*Y 
                for k in range(10): 
                    ZZ = Z - (Z**4 + 1)/(4*Z**3)
                    Z = ZZ
                    W = f(Z)
                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-3.5*L,4*L)
                surf = ax.plot_surface(X, Y, -W, rstride=1, cstride=1, cmap="Oranges")
                plt.show() 
        
        # Configurar la imagen
        imgx = 300; imgy = 300
        image1 = Image.new("RGB", (imgx, imgy)); image3 = Image.new("RGB", (imgx, imgy)) 
        image4 = Image.new("RGB", (imgx, imgy)); image5 = Image.new("RGB", (imgx, imgy))
        xa = -4; xb = 4
        ya = -4; yb = 4
        maxit = 15; h = 1e-6; eps = 1e-3

        # Definir las funciones
        def f1(x):
            return x**2+1
        def f2(x):
            return x**3+x**2+1
        def f3(x):
            return x**4+x**3+x**2+1
        def f4(x):
            return x**5+x**4+x**3+x**2+1

        # Aplicando método de Newton  
        if Funcion == 'x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx = x*(xb-xa)/(imgx-1)+xa; z = complex(zx, zy)
                    for i in range(maxit):
                        dz = (f1(z+complex(h,h))-f1(z))/complex(h,h); z0 = z-f1(z)/dz
                        if abs(z0-z)<eps:
                            break
                        z = z0
                        r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                        r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                        r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                        r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        if Funcion == 'x^3+x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx = x*(xb-xa)/(imgx-1)+xa; z = complex(zx, zy)
                    for i in range(maxit):
                        dz = (f2(z+complex(h,h))-f2(z))/complex(h,h); z0 = z-f2(z)/dz; 
                        if abs(z0-z)<eps:
                            break
                        z = z0
                        r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                        r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                        r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                        r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b))
            expr1=spp.latex("x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**3+x**2+1

        if Funcion == 'x^4+x^3+x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx = x*(xb-xa)/(imgx-1)+xa; z = complex(zx, zy)
                    for i in range(maxit):
                        dz = (f3(z+complex(h,h))-f3(z))/complex(h,h); z0 = z-f3(z)/dz; 
                        if abs(z0-z)<eps:
                            break
                        z = z0
                        r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                        r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                        r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                        r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b))
            expr1=spp.latex("x^4+x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**4+x**3+x**2+1

        if Funcion == "x^5+x^4+x^3+x^2+1":
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx = x*(xb-xa)/(imgx-1)+xa; z = complex(zx, zy)
                    for i in range(maxit):
                        dz = (f4(z+complex(h,h))-f4(z))/complex(h,h); z0 = z-f4(z)/dz; 
                        if abs(z0-z)<eps:
                            break
                        z = z0
                        r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                        r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                        r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                        r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b))
            expr1=spp.latex("x^5+x^4+x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**5+x**4+x**3+x**2+1

        def color(Grises, Azul, Naranja, Verde):
            try:
                fig, axs = plt.subplots(1,2, figsize = (14,7))
                fig.suptitle(display(Markdown("La velocidad y el punto de convergencia para la función, $"+expr1+"$ estará dado por:")))
                axs[0].set_title('Función en el plano real'); axs[0].plot(x, y, 'r-.', linewidth = 3.5); axs[0].grid(True)
                axs[0].set_xlabel('Eje x'); axs[0].set_ylabel('Eje y')
                axs[1].set_xlabel('Píxeles Horizontales'); axs[1].set_ylabel('Píxeles Verticales')

                if Grises == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image1); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Azul == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image3); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Naranja == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image4); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Verde == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image5); axs[1].grid(True, linewidth = 0.35)
                    plt.show()
            except:
                pass
        interact(color, Grises = False, Azul = False, Naranja = False, Verde = False)
        interact(newton3D, Tres_Dimensiones = widgets.Combobox(options = ['Gráfica 1', 'Gráfica 2', 'Gráfica 3']), value = None)
    except:
        pass
def julia(Funcion):
    try:
        def julia3D(Tres_Dimensiones):
            fig = plt.figure(figsize = (14,7)) 
            ax = fig.add_subplot(111, projection='3d')
            ax.view_init(azim=-90,elev=50) 
            ax.dist = 5; M = 200 # pixels

            if Tres_Dimensiones == 'Gráfica 1':
                dx = -0.1 ; dy = 0.0; L = 1.7; ax.set_facecolor([0.0,0.3,0.6])
                def f(Z): 
                    return np.e**(-np.abs(Z))
                x = np.linspace(-L+dx,L+dx,M); y = np.linspace(-L+dy,L+dy,M)
                X,Y = np.meshgrid(x,y)
                cX = -0.7454294; cY = 0; C = cX + 1j*cY 
                W = np.zeros((M,M)); Z = X + 1j*Y 
                for k in range(17): 
                    ZZ = Z**2 + C
                    Z = ZZ
                    W = f(Z) 
                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-.8*L,1.5*L)
                ax.contourf3D(X, Y, W, 2*7, cmap="gist_heat_r")
                plt.show()

            if Tres_Dimensiones == 'Gráfica 2':
                dx = 0.0 ; dy = 0.0; L = 2.0; ax.set_facecolor([0.5,0.0,0.0])
                def f(Z): # def scale damping of the depth function
                    return np.e**(-np.abs(Z))
                x = np.linspace(-L+dx,L+dx,M); y = np.linspace(-L+dy,L+dy,M)
                X,Y = np.meshgrid(x,y); cX = -0.7454294; cY = 0; C = cX + 1j*cY 
                W = np.zeros((M,M)); Z = X + 1j*Y 
                for k in range(7): 
                    ZZ = Z*Z + C
                    Z = ZZ
                    W = f(Z)
                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-2*L,2*L)
                surf = ax.plot_surface(X, Y, -W, rstride=1, cstride=1, cmap="jet")
                plt.show()

            if Tres_Dimensiones == 'Gráfica 3':
                dx = -0.1 ; dy = 0.0; L = 2.0; ax.set_facecolor([0.7,0.0,0.0])
                def f(Z): # def scale damping of the depth function
                    return np.e**(-np.abs(Z))
                x = np.linspace(-L+dx,L+dx,M); y = np.linspace(-L+dy,L+dy,M)
                X,Y = np.meshgrid(x,y); cX = -0.7454294; cY = 0; C = cX + 1j*cY 
                W = np.zeros((M,M)); Z = X + 1j*Y 
                for k in range(7): 
                    ZZ = Z*Z + C
                    Z = ZZ
                    W = f(Z)
                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-1.5*L,1.5*L)
                ax.contourf3D(X, Y, -W, 2*7, cmap="RdYlBu")
                plt.show() 

        # Configurar la imagen
        imgx = 300; imgy = 300
        image1 = Image.new("RGB", (imgx, imgy)); image3 = Image.new("RGB", (imgx, imgy)) 
        image4 = Image.new("RGB", (imgx, imgy)); image5 = Image.new("RGB", (imgx, imgy))
        xa = -4; xb = 4
        ya = -4; yb = 4
        maxit = 20

        # Definir las funciones
        def f1(z):
            return z**2+complex(1,1)
        def f2(z):
            return z**3+z**2+complex(1,1)
        def f3(z):
            return z**4+z**3+z**2+complex(1,1)
        def f4(z):
            return z**5+z**4+z**3+z**2+complex(1,1)

        #Distancia del punto al conjunto
        def distPC(Z,z):
            d0=100
            item=0
            for i in range(len(Z)):
                d=abs(i-z)
                if d<d0:
                    d0=d
                    item=i
                else:
                    None
            return d0,item

        # Aplicando método de Newton  
        if Funcion == 'x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx=x*(xb-xa)/(imgx-1)+xa
                    z=complex(zx,zy)
                    for i in range (maxit):
                        z0=f1(z)
                        if abs(z)>1000:
                            break
                        z=z0

                    z=z0

                    r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                    r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                    r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                    r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        if Funcion == 'x^3+x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx=x*(xb-xa)/(imgx-1)+xa
                    z=complex(zx,zy)
                    for i in range (maxit):
                        z0=f2(z)
                        if abs(z)>1000:
                            break
                        z=z0
                    z=z0
                    r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                    r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                    r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                    r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        if Funcion == 'x^4+x^3+x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx=x*(xb-xa)/(imgx-1)+xa
                    z=complex(zx,zy)
                    for i in range (maxit):
                        z0=f3(z)
                        if abs(z)>1000:
                            break
                        z=z0
                    z=z0
                    r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                    r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                    r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                    r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x^4+x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        if Funcion == 'x5+x^4+x^3+x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx=x*(xb-xa)/(imgx-1)+xa
                    z=complex(zx,zy)
                    for i in range (maxit):
                        z0=f4(z)
                        if abs(z)>1000:
                            break
                        z=z0

                    z=z0

                    r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                    r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                    r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                    r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x5+x^4+x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        def color(Grises, Azul, Naranja, Verde):
            try:
                fig, axs = plt.subplots(1,2, figsize = (14,7))
                fig.suptitle(display(Markdown("La velocidad y el punto de convergencia para la función, $"+expr1+"$ estará dado por:")))
                axs[0].set_title('Función en el plano real'); axs[0].plot(x, y, 'r-.', linewidth = 3.5); axs[0].grid(True)
                axs[0].set_xlabel('Eje x'); axs[0].set_ylabel('Eje y')
                axs[1].set_xlabel('Píxeles Horizontales'); axs[1].set_ylabel('Píxeles Verticales')

                if Grises == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image1); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Azul == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image3); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Naranja == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image4); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Verde == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image5); axs[1].grid(True, linewidth = 0.35)
                    plt.show()
            except:
                pass
        interact(color, Grises = False, Azul = False, Naranja = False, Verde = False)
        interact(julia3D, Tres_Dimensiones = widgets.Combobox(options = ['Gráfica 1', 'Gráfica 2', 'Gráfica 3']), value = None)
    except:
        pass
def mandelbrot(Funcion):
    try:
        def mandelbrot3D(Tres_Dimensiones):
            fig = plt.figure(figsize = (14,7)) 
            ax = fig.add_subplot(111, projection='3d')
            ax.view_init(azim=-90,elev=50) 
            ax.dist = 4.5; M = 200 # pixels

            if Tres_Dimensiones == 'Gráfica 1' :
                dx = -0.7 ; dy = 0.0; L = 2.0; ax.set_facecolor([0.5,0.0,0.0])
                def f(Z): 
                    return np.e**(-np.abs(Z))

                x = np.linspace(-L+dx,L+dx,M); y = np.linspace(-L+dy,L+dy,M)
                X,Y = np.meshgrid(x,y)
                Z = np.zeros(M); W = np.zeros((M,M)); C = X + 1j*Y 

                for k in range(9): 
                    ZZ = Z**2 + C
                    Z = ZZ
                    W = f(Z) 

                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-L,2*L)
                ax.plot_surface(X, Y, W, rstride=1, cstride=1, cmap="cividis")
                plt.show()

            if Tres_Dimensiones == 'Gráfica 2':
                dx = -0.7 ; dy = 0.0; L = 2.0; ax.set_facecolor([0.5,0.0,0.0])
                x = np.linspace(dx-L,dx+L,M); y = np.linspace(dy-L,dy+L,M) 
                X,Y = np.meshgrid(x,y,sparse=True) 
                Z = np.zeros(M); C = X + 1j*Y 
                for k in range(15): 
                    ZZ = Z*Z + C
                    Z = ZZ
                    W = np.e**(-.6*np.abs(Z))

                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-L,L)
                surf = ax.plot_surface(X, Y, -W, cmap= "gist_rainbow",linewidth=0, antialiased=False)
                plt.show()

            if Tres_Dimensiones == 'Gráfica 3' :
                dx = -0.6 ; dy = 0.0; L = 1.3; ax.set_facecolor([0.0,0.0,0.0])
                def f(Z):
                    return np.e**(-np.abs(Z))
                x = np.linspace(-L+dx,L+dx,M); y = np.linspace(-L+dy,L+dy,M) 
                X,Y = np.meshgrid(x,y); Z = np.zeros(M); W = np.zeros((M,M)); C = X + 1j*Y 
                for k in range(17): 
                    ZZ = Z**2 + C
                    Z = ZZ
                    W = f(Z)

                ax.set_xlim(dx-L,dx+L); ax.set_zlim(dy-L,dy+L); ax.set_zlim(-.5*L,1.5*L)
                ax.contourf3D(X, Y, W, 2*17, cmap="ocean")
                plt.show() 
                
        # Configurar la imagen
        imgx = 300; imgy = 300
        image1 = Image.new("RGB", (imgx, imgy)); image3 = Image.new("RGB", (imgx, imgy)) 
        image4 = Image.new("RGB", (imgx, imgy)); image5 = Image.new("RGB", (imgx, imgy))
        xa = -3; xb = 3
        ya = -3; yb = 3
        maxit=20

        # Definir las funciones
        def f1(z,a,b):
            return z**2+complex(a,b)
        def f2(z,a,b):
            return z**3+z**2+complex(a,b)
        def f3(z,a,b):
            return z**4+z**2+complex(a,b)
        def f4(z,a,b):
            return z**5+z**2+complex(a,b)

        # Aplicando método de Newton 
        if Funcion == 'x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx=x*(xb-xa)/(imgx-1)+xa
                    z=0
                    for i in range (maxit):
                        z0=f1(z,zx,zy)
                        if abs(z)>1000:
                            break
                        z=z0

                        r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                        r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                        r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                        r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        if Funcion == 'x^3+x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx=x*(xb-xa)/(imgx-1)+xa
                    z=0
                    for i in range (maxit):
                        z0=f2(z,zx,zy)
                        if abs(z)>1000:
                            break
                        z=z0

                        r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                        r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                        r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                        r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        if Funcion == 'x^4+x^3+x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx=x*(xb-xa)/(imgx-1)+xa
                    z=0
                    for i in range (maxit):
                        z0=f3(z,zx,zy)
                        if abs(z)>1000:
                            break
                        z=z0

                        r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                        r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                        r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                        r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x^4+x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        if Funcion == 'x^5+x^4+x^3+x^2+1':
            for y in range(imgy):
                zy = y*(yb-ya)/(imgy-1)+ya
                for x in range(imgx):
                    zx=x*(xb-xa)/(imgx-1)+xa
                    z=0
                    for i in range (maxit):
                        z0=f4(z,zx,zy)
                        if abs(z)>1000:
                            break
                        z=z0

                        r = i*8; g = i*8; b = i*8; image1.putpixel((x,y), (r,g,b))
                        r = i*8; g = i*12; b = i*43; image3.putpixel((x,y), (r,g,b))
                        r = i*50; g = i*16; b = i*6; image4.putpixel((x,y), (r,g,b))
                        r = i*21; g = i*47; b = i*14; image5.putpixel((x,y), (r,g,b)) 
            expr1=spp.latex("x^5+x^4+x^3+x^2+1")
            x = np.arange(-10, 10, 0.1); y = x**2+1

        def color(Grises, Azul, Naranja, Verde):
            try:
                fig, axs = plt.subplots(1,2, figsize = (14,7))
                fig.suptitle(display(Markdown("La velocidad y el punto de convergencia para la función, $"+expr1+"$ estará dado por:")))
                axs[0].set_title('Función en el plano real'); axs[0].plot(x, y, 'r-.', linewidth = 3.5); axs[0].grid(True)
                axs[0].set_xlabel('Eje x'); axs[0].set_ylabel('Eje y')
                axs[1].set_xlabel('Píxeles Horizontales'); axs[1].set_ylabel('Píxeles Verticales')

                if Grises == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image1); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Azul == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image3); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Naranja == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image4); axs[1].grid(True, linewidth = 0.35)
                    plt.show()

                if Verde == True:
                    axs[1].set_title('Fractal en el plano complejo'); axs[1].imshow(image5); axs[1].grid(True, linewidth = 0.35)
                    plt.show()
            except:
                pass
                
        interact(color, Grises = False, Azul = False, Naranja = False, Verde = False)
        interact(mandelbrot3D, Tres_Dimensiones = widgets.Combobox(options = ['Gráfica 1', 'Gráfica 2', 'Gráfica 3']), value = None)
    except:
        pass
def barnsley(Gráfica):
    try:
        if Gráfica == True:
            x = [] ; y = [] 
            x.append(0); y.append(0) 
            current = 0

            for i in range(1, 50000): 
                # generates a random integer between 1 and 100 
                z = randint(1, 100) 

                # for the probability 0.01 
                if z == 1: 
                    x.append(0) 
                    y.append(0.16*(y[current])) 

                # for the probability 0.85	 
                if z>= 2 and z<= 86: 
                    x.append(0.85*(x[current]) + 0.04*(y[current])) 
                    y.append(-0.04*(x[current]) + 0.85*(y[current])+1.6) 

                # for the probability 0.07	 
                if z>= 87 and z<= 93: 
                    x.append(0.2*(x[current]) - 0.26*(y[current])) 
                    y.append(0.23*(x[current]) + 0.22*(y[current])+1.6) 

                # for the probability 0.07	 
                if z>= 94 and z<= 100: 
                    x.append(-0.15*(x[current]) + 0.28*(y[current])) 
                    y.append(0.26*(x[current]) + 0.24*(y[current])+0.44) 
                current = current + 1

            plt.scatter(x, y, s = 0.2, edgecolor ='green') 
            plt.grid(); plt.show()
        else:
            None
    except:
        pass
tab_contents = ['Conjuntos de Newton','Conjuntos de Julia', 'Algoritmo determinista: Conjunto de Mandelbrot', 'Algoritmo aleatorio: Helecho de Barnsley']
funcion=[interactive(newton, Funcion = widgets.Combobox(options = ["x^2+1", 'x^3+x^2+1', "x^4+x^3+x^2+1", "x^5+x^4+x^3+x^2+1"]), value = None),
         interactive(julia, Funcion = widgets.Combobox(options=["x^2+1", 'x^3+x^2+1', "x^4+x^3+x^2+1", "x^5+x^4+x^3+x^2+1"]), value = None),
         interactive(mandelbrot, Funcion = widgets.Combobox(options = ["x^2+1", 'x^3+x^2+1', "x^4+x^3+x^2+1", "x^5+x^4+x^3+x^2+1"]), value = None),
         interactive(barnsley, Gráfica = False)]

tab = widgets.Accordion()
tab.children = [widgets.VBox(children = i.children) for i in funcion]
for i in range(len(tab_contents)):
    tab.set_title(i,tab_contents[i])
display(tab)
# Out:
# Accordion(children=(VBox(children=(Combobox(value='', description='Funcion', options=('x^2+1', 'x^3+x^2+1', 'x…
